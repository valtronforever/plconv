# %%
import pandas as pd
from IPython.display import display
from pathlib import Path

df = pd.read_csv(Path('pg.mmo'), encoding='cp1251', sep='\t', names=range(23))
df_head = df[:3]
df_body = df[3:]
df_body[0] = df_body[4]
df = df_head.append(df_body, ignore_index=True)
df.to_csv(Path('pg_new.mmo'), encoding='cp1251', sep='\t', index=False, header=False)
display(df)
# Out:
# <ipython-input-27-1ea4835179d9>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_body[0] = df_body[4]
#                                                    0   \
# 0                                 РАСХОДНАЯ_НАКЛАДНАЯ
# 1                                       17171/0011323
# 2   ; Херсонська обл., Каланчацький р-н, смт. Кала...
# 3                                       8001090378255
# 4                                       8888826016588
# 5                                       8001090378217
# 6                                       8001090378293
# 7                                       8001090909800
# 8                                       8001090910080
# 9                                       3014260104757
# ...
