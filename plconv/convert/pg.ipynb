# %%
import pandas as pd
from IPython.display import display
from pathlib import Path

df = pd.read_excel(Path('pg.xls'))
header_str = "Номер п/п"
header_row = df.index.get_loc(df.index[df['Unnamed: 0'] == header_str][0])
df = pd.read_excel(Path('pg.xls'), header=header_row + 1, converters={'Штрихкод':str})
df = df[df['Штрихкод'].notnull()]
df = df.rename(columns={df.columns[4]: 'Цена'})
df.insert(loc=df.columns.get_loc("Цена") + 1, column='НДС', value=20)
df.insert(loc=df.columns.get_loc("Наименование") + 1, column='Производитель', value='Procter & Gamble')
df = df[(df['Штрихкод'].str.isnumeric()) & (df['Штрихкод'].str.len() == 13)]
df = df[['Наименование', 'Производитель', 'Цена', 'НДС', 'ШТ/Кейс', 'Штрихкод']]
display(df)
# Out:
#                                            Наименование     Производитель  \
# 1     ALWAYS Прокладки гiгiєнiчнi щоденнi ароматизов...  Procter & Gamble
# 2     ALWAYS Прокладки гiг щоденнi ароматизованiНепо...  Procter & Gamble
# 3     ALWAYS Прокладки гiг щоденнi ароматизованi Неп...  Procter & Gamble
# 4     ALWAYS Прокладки гiгiєнiчнi щоденнi ароматизов...  Procter & Gamble
# 5     ALWAYS Прокладки гiгiєнiчнi щоденнi ароматизов...  Procter & Gamble
# ...                                                 ...               ...
# 1035  PAMPERS Дитячі вологі серветки Pure Protection...  Procter & Gamble
# 1036  PAMPERS Дитячі вологі серветки Pure Protection...  Procter & Gamble
# 1037  PAMPERS Дитячі вологі серветки Fresh Clean 4х5...  Procter & Gamble
# 1038  PAMPERS Дитячі вологі серветки Sensitive 4x52 ...  Procter & Gamble
# 1039  PAMPERS Дитячі вологі серветки Pure Protection...  Procter & Gamble
#
#         Цена  НДС  ШТ/Кейс       Штрихкод
# 1      42.08   20     14.0  8001841009414
# 2      56.15   20      5.0  8001841009513
# 3      42.08   20     10.0  8001841009353
# 4      58.96   20      6.0  8001841009445
# 5      58.96   20      5.0  8001841009384
# ...      ...  ...      ...            ...
# 1035  109.22   20      9.0  8001841708874
# 1036  161.36   20      6.0  8001841708942
# 1037  139.83   20      3.0  8001841077949
# 1038  139.83   20      3.0  8001841062624
# 1039  484.10   20      1.0  8001841709017
#
# [991 rows x 6 columns]
